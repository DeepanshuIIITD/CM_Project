# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv('c4m_data2.csv')

# %%
data
# Out:
#       Unnamed: 0   CTRL_4H  CTRL_24H  SWTX143_50mpk_4h  SWTX143_50mpk_24h  \
# 0        DDX11L1  0.000006  0.000000          0.000000           0.000000
# 1         WASH7P  0.001106  0.001311          0.001465           0.001320
# 2      MIR6859-1  0.000000  0.000000          0.000000           0.000000
# 3      MIR6859-2  0.000000  0.000000          0.000000           0.000000
# 4      MIR6859-3  0.000000  0.000000          0.000000           0.000000
# ...          ...       ...       ...               ...                ...
# 27059     HDGFL1  0.000000  0.000000          0.000000           0.000000
# 27060      DHX57  0.002289  0.002450          0.003254           0.003117
# 27061       LTV1  0.003104  0.002443          0.003248           0.002671
# 27062      HLA-H  0.001914  0.001910          0.002746           0.002552
# 27063     LONRF1  0.001404  0.001500          0.001198           0.001140
#
#        SWTX143_25mpk_4h  SWTX143_25mpk_24h  SWTX143_10mpk_4h  \
# ...

# %%
# import pandas as pd
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import f_classif

# # Load your data
# # Replace 'data.csv' with your file path
# data = pd.read_csv('c4m_data2.csv')

# # Separate normal and cancer samples (4H)
# normal_sample = data['CTRL_4H']
# cancer_samples_4H = data[data.columns[data.columns.str.endswith('4h')]]
# cancer_samples_4H = data['SWTX143_50mpk_4h','SWTX143_25mpk_4h','SWTX143_10mpk_4h']

# # Perform differential gene expression analysis
# # Using ANOVA F-value to select top significant genes
# selector = SelectKBest(score_func=f_classif, k='all')
# selector.fit(cancer_samples_4H, normal_sample)

# # Get p-values and scores of genes
# p_values = pd.DataFrame({'Gene': data.columns[data.columns.str.endswith('4h')],
#                          'p_value': selector.pvalues_,
#                          'score': selector.scores_})

# # Filter significant genes based on p-value threshold (e.g., 0.05)
# significant_genes = p_values[p_values['p_value'] < 0.000000000000000005]

# # Display significant genes
# print(significant_genes)
# print(cancer_samples_4H)

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, classification_report
# ##############
# ##############
# ##############
# data = pd.read_csv('c4m_data2.csv')
# # Separate features (genes) and labels (sample classes)
# features = data.drop(columns=['Unnamed: 0'])
# # labels = data['CTRL_4H']  # Replace 'Class_Label_Column' with your label column

# # Assuming 'CTRL_4H' contains categorical classes

# # Continue with the rest of your code using 'labels' as the updated categorical labels

# # Split the data into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# # Model Training (using RandomForestClassifier as an example)
# model = RandomForestClassifier(n_estimators=100, random_state=42)
# model.fit(X_train, y_train)

# # Model Prediction
# y_pred = model.predict(X_test)

# # Model Evaluation
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {accuracy}")

# # Classification Report
# print(classification_report(y_test, y_pred))

# # Use the trained model for prediction on new/unseen data
# # Replace 'new_data_features' with features of new data
# # new_data_predictions = model.predict(new_data_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      10 features = data.drop(columns=['Unnamed: 0'])
#      11 # labels = data['CTRL_4H']  # Replace 'Class_Label_Column' with your label column
#      12
#      13 # Assuming 'CTRL_4H' contains categorical classes
#    (...)
#      16
#      17 # Split the data into training and testing sets
# ---> 18 X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
#      20 # Model Training (using RandomForestClassifier as an example)
#      21 model = RandomForestClassifier(n_estimators=100, random_state=42)
#
# NameError: name 'labels' is not defined

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(data['CTRL_4H'])

# %%
labels
# Out:
# array([   3, 4876,    0, ..., 8263, 6565, 5564])

# %%
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report, accuracy_score
# from sklearn.model_selection import StratifiedShuffleSplit
# # Load the dataset
# ########################
# df = pd.read_csv('c4m_data2.csv')
# # Extract relevant columns for analysis
# gene_columns = df['CTRL_4H', 'SWTX143_50mpk_4h', 'SWTX143_25mpk_4h', 'SWTX143_10mpk_4h']
# selected_data = data[['Unnamed: 0'] + gene_columns]

# # Creating labels: 0 for normal (CTRL_4H) and 1 for cancer (other samples)
# selected_data['label'] = selected_data.apply(lambda row: 0 if row['CTRL_4H'] > 0 else 1, axis=1)

# # Prepare data for modeling
# X = selected_data[gene_columns]
# y = selected_data['label']

# # Split the data into 70% training and 30% testing using stratified split
# sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
# for train_index, test_index in sss.split(X, y):
#     X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#     y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# # Train a Random Forest Classifier
# model = RandomForestClassifier(n_estimators=100, random_state=42)
# model.fit(X_train, y_train)

# # Predict on the test set
# y_pred = model.predict(X_test)

# # Evaluate the model
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {accuracy}")

# # You can now use this trained model to predict the likelihood of a patient having cancer
# # For example, given gene expressions of a new patient, predict the likelihood of cancer and the resembling sample type.
# # new_patient_data = ... # Gene expressions of the new patient
# # prediction = model.predict(new_patient_data)
# # print(prediction)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('CTRL_4H', 'SWTX143_50mpk_4h', 'SWTX143_25mpk_4h', 'SWTX143_10mpk_4h')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Extract relevant columns for analysis for 'CTRL_24H', 'SWTX143_50mpk_24h', 'SWTX143_25mpk_24h', 'SWTX143_10mpk_24h'
gene_columns_24h = ['CTRL_24H', 'SWTX143_50mpk_24h', 'SWTX143_25mpk_24h', 'SWTX143_10mpk_24h']
selected_data_24h = data[['Unnamed: 0'] + gene_columns_24h]

# Creating labels: 0 for normal (CTRL_24H) and 1 for cancer (other samples)
selected_data_24h['label'] = selected_data_24h.apply(lambda row: 0 if row['CTRL_24H'] > 0 else 1, axis=1)

# Prepare data for modeling for 'CTRL_24H', 'SWTX143_50mpk_24h', 'SWTX143_25mpk_24h', 'SWTX143_10mpk_24h'
X_24h = selected_data_24h[gene_columns_24h]
y_24h = selected_data_24h['label']

# Split the data into 70% training and 30% testing for 'CTRL_24H', 'SWTX143_50mpk_24h', 'SWTX143_25mpk_24h', 'SWTX143_10mpk_24h'
X_train_24h, X_test_24h, y_train_24h, y_test_24h = train_test_split(X_24h, y_24h, test_size=0.3, random_state=42)

# Train a Random Forest Classifier for 'CTRL_24H', 'SWTX143_50mpk_24h', 'SWTX143_25mpk_24h', 'SWTX143_10mpk_24h'
model_24h = RandomForestClassifier(n_estimators=100, random_state=42)
model_24h.fit(X_train_24h, y_train_24h)

# Predict on the test set for 'CTRL_24H', 'SWTX143_50mpk_24h', 'SWTX143_25mpk_24h', 'SWTX143_10mpk_24h'
y_pred_24h = model_24h.predict(X_test_24h)

# Evaluate the model for 'CTRL_24H', 'SWTX143_50mpk_24h', 'SWTX143_25mpk_24h', 'SWTX143_10mpk_24h'
print(classification_report(y_test_24h, y_pred_24h))
accuracy = accuracy_score(y_test_24h, y_pred_24h)
print(f"Accuracy: {accuracy}")
# Out:
# /var/folders/dl/4321kd_d56vfmc6wl8zndc740000gn/T/ipykernel_4142/3962588821.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data_24h['label'] = selected_data_24h.apply(lambda row: 0 if row['CTRL_24H'] > 0 else 1, axis=1)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5722
#            1       1.00      1.00      1.00      2398
#
#     accuracy                           1.00      8120
#    macro avg       1.00      1.00      1.00      8120
# weighted avg       1.00      1.00      1.00      8120
#
# Accuracy: 1.0
